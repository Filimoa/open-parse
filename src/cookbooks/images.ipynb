# %%
import sys

sys.path.append("..")

# !mkdir -p sample-docs
# !wget https://sergey-filimonov.nyc3.digitaloceanspaces.com/open-parse/sample-docs/pdf-with-image.pdf -O sample-docs/pdf-with-image.pdf
# Out:
# --2024-11-12 17:26:57--  https://sergey-filimonov.nyc3.digitaloceanspaces.com/open-parse/sample-docs/pdf-with-image.pdf
# Resolving sergey-filimonov.nyc3.digitaloceanspaces.com (sergey-filimonov.nyc3.digitaloceanspaces.com)... 162.243.189.2
# Connecting to sergey-filimonov.nyc3.digitaloceanspaces.com (sergey-filimonov.nyc3.digitaloceanspaces.com)|162.243.189.2|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 62731 (61K) [application/pdf]
# Saving to: ‘sample-docs/pdf-with-image.pdf’
#
# sample-docs/pdf-wit 100%[===================>]  61.26K  --.-KB/s    in 0.06s
#
# 2024-11-12 17:26:57 (1.06 MB/s) - ‘sample-docs/pdf-with-image.pdf’ saved [62731/62731]

# %%
import openparse

parser = openparse.DocumentParser()
parsed = parser.parse("sample-docs/pdf-with-image.pdf")

for node in parsed.nodes:
    print(len(node.elements))
    display(node)
# Out:
# 6
# ...
